# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

# %%
mul_1 = pd.read_csv('https://gitlab.com/mirsakhawathossain/exodata/-/raw/main/dataset/multi_col_1.csv').sort_index(axis=0)

# %%
mul_2 = pd.read_csv('https://gitlab.com/mirsakhawathossain/exodata/-/raw/main/dataset/multi_col_2.csv').sort_index(axis=0)

# %%
mul_3 = pd.read_csv('https://gitlab.com/mirsakhawathossain/exodata/-/raw/main/dataset/multi_col_3.csv').sort_index(axis=0)

# %%
mul_4 = pd.read_csv('https://gitlab.com/mirsakhawathossain/exodata/-/raw/main/dataset/multi_col_4.csv').sort_index(axis=0)

# %%
display(mul_1, mul_2, mul_3, mul_4)
# Out:
#      VIF Factor                                           Features
# 0      1.000432                     PDCSAP_FLUX__has_duplicate_max
# 1      1.003671                     PDCSAP_FLUX__has_duplicate_min
# 2      0.002766                         PDCSAP_FLUX__has_duplicate
# 3     51.626670                            PDCSAP_FLUX__sum_values
# 4     14.006825                            PDCSAP_FLUX__abs_energy
# ..          ...                                                ...
# 195   15.698682  PDCSAP_FLUX__change_quantiles__f_agg_"mean"__i...
# 196   32.049260  PDCSAP_FLUX__change_quantiles__f_agg_"var"__is...
# 197    1.292930  PDCSAP_FLUX__change_quantiles__f_agg_"mean"__i...
# 198   18.137020  PDCSAP_FLUX__change_quantiles__f_agg_"var"__is...
# 199   18.685205  PDCSAP_FLUX__change_quantiles__f_agg_"mean"__i...
#
# [200 rows x 2 columns]
#       VIF Factor                                           Features
# 0      73.726231  PDCSAP_FLUX__change_quantiles__f_agg_"var"__is...
# ...

# %%
mul_concat = pd.concat([mul_1, mul_2, mul_3, mul_4], axis=0)

# %%
mul_concat
# Out:
#        VIF Factor                                           Features
# 0        1.000432                     PDCSAP_FLUX__has_duplicate_max
# 1        1.003671                     PDCSAP_FLUX__has_duplicate_min
# 2        0.002766                         PDCSAP_FLUX__has_duplicate
# 3       51.626670                            PDCSAP_FLUX__sum_values
# 4       14.006825                            PDCSAP_FLUX__abs_energy
# ..            ...                                                ...
# 136   2680.186847  PDCSAP_FLUX__permutation_entropy__dimension_4_...
# 137   4066.314266  PDCSAP_FLUX__permutation_entropy__dimension_5_...
# 138   2036.645274  PDCSAP_FLUX__permutation_entropy__dimension_6_...
# 139    251.919599  PDCSAP_FLUX__permutation_entropy__dimension_7_...
# 140  34545.835786  PDCSAP_FLUX__mean_n_absolute_max__number_of_ma...
#
# [741 rows x 2 columns]

# %%
#mul_concat.to_csv('/home/idies/workspace/Storage/s.hossain18/persistent/multi_col_total.csv', index=False)

# %%
t= mul_concat['VIF Factor']>5

# %%
t.value_counts()
# Out:
# True     505
# False    236
# Name: VIF Factor, dtype: int64

# %%
mul_concat[mul_concat['VIF Factor']>5]['Features'].to_list()
# Out:
# ['PDCSAP_FLUX__sum_values',
#  'PDCSAP_FLUX__abs_energy',
#  'PDCSAP_FLUX__mean_abs_change',
#  'PDCSAP_FLUX__median',
#  'PDCSAP_FLUX__mean',
#  'PDCSAP_FLUX__standard_deviation',
#  'PDCSAP_FLUX__variance',
#  'PDCSAP_FLUX__root_mean_square',
#  'PDCSAP_FLUX__absolute_sum_of_changes',
#  'PDCSAP_FLUX__sum_of_reoccurring_values',
#  'PDCSAP_FLUX__sum_of_reoccurring_data_points',
#  'PDCSAP_FLUX__maximum',
#  'PDCSAP_FLUX__absolute_maximum',
#  'PDCSAP_FLUX__minimum',
#  'PDCSAP_FLUX__time_reversal_asymmetry_statistic__lag_1',
#  'PDCSAP_FLUX__time_reversal_asymmetry_statistic__lag_2',
#  'PDCSAP_FLUX__time_reversal_asymmetry_statistic__lag_3',
#  'PDCSAP_FLUX__c3__lag_1',
#  'PDCSAP_FLUX__c3__lag_2',
#  'PDCSAP_FLUX__c3__lag_3',
#  'PDCSAP_FLUX__cid_ce__normalize_False',
#  'PDCSAP_FLUX__quantile__q_0.1',
#  'PDCSAP_FLUX__quantile__q_0.2',
#  'PDCSAP_FLUX__quantile__q_0.3',
#  'PDCSAP_FLUX__quantile__q_0.4',
#  'PDCSAP_FLUX__quantile__q_0.6',
#  'PDCSAP_FLUX__quantile__q_0.7',
# ...
